# %% [markdown]
# <a href="https://colab.research.google.com/github/iniho/Python/blob/main/16thFebPratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x =5
print(x)
# Out:
# 5

# %%
print("Hi, Guys")
# Out:
# Hi, Guys

# %%
def calculate_subtotal(price, quantity):

    return price * quantity

def calculate_tax(amount):

    tax_rate = 0.08

    return amount * tax_rate

def calculate_shipping(subtotal):

    if subtotal >= 50:

        return 0              # Free shipping

    else:

        return 5.99

def calculate_total(price, quantity):

    subtotal = calculate_subtotal(price, quantity)

    tax = calculate_tax(subtotal)

    shipping = calculate_shipping(subtotal)

    total = subtotal + tax + shipping

    return total

# Test the shopping cart

item_price = 15.99

item_quantity = 4

final_cost = calculate_total(item_price, item_quantity)

print("Final total: $" + str(round(final_cost, 2)))

# Test with cheaper order

final_cost2 = calculate_total(10, 2)

print("Final total: $" + str(round(final_cost2, 2)))
